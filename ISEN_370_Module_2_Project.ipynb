# %% [markdown]
# <a href="https://colab.research.google.com/github/ncat-morrow/isen-project-1-ncat-engineers/blob/main/ISEN_370_Module_2_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ISEN 370 Project 2 Assignment
# In this assignment, you will use data science tools to exlore two datasets, calculate confidence intervals and conduct a hypothesis testing on the given datasets.
# You can use ISEN 370 Project 2 Demo file as a reference when completing this assignment.

# %% [markdown]
# First, you will need to import required libraries to the project.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %% [markdown]
# ## Data Import
#
# The Learning Enhanced Watershed Assessment System (LEWAS) is a unique real-time water and weather monitoring system. The LEWAS monitoring site is installed at the outfall of the Webb Branch watershed on Virginia Tech’s campus. Webb Branch is an urban stream with a 2.78 square kilometer (about one square mile) watershed consisting of residential and commercial properties. The stream is routed through man-made channels and culverts until it discharges at the LEWAS monitoring site. We first import the LEWAS datasets and print the first 10 rows of data. The data is stored in CSV files for which the path is given in the cell below. There are two CSV files, the first contains data from 9/01/17-9/30/17 and the second contains data from 10/01/17-10/31/17.
# The following codes provide the link to where the data are stored.

# %%
data_url3='https://github.com/StevenXJiang/DataScienceModule2/raw/main/LEWAS_Storm_Data_Demo_3.csv'
data_url4='https://github.com/StevenXJiang/DataScienceModule2/raw/main/LEWAS_Storm_Data_Demo_4.csv'

# %% [markdown]
# ## Exploring Data

# %% [markdown]
# * Display the first 10 rows of data ufor each of the two data sets mentioned above.

# %%
df1=pd.read_csv(data_url3)
df1.head(10)
# Out:
#      Date and Time  Water Temperature (F)  Est. Flow Rate[m^3/s]
# 0  9/1/17 12:01 AM                 66.236               0.051211
# 1  9/1/17 12:04 AM                 66.236               0.042161
# 2  9/1/17 12:07 AM                 66.146               0.029130
# 3  9/1/17 12:10 AM                 66.200               0.029003
# 4  9/1/17 12:13 AM                 66.236               0.023817
# 5  9/1/17 12:16 AM                 66.254               0.013823
# 6  9/1/17 12:19 AM                 66.272               0.010061
# 7  9/1/17 12:22 AM                 66.290               0.008013
# 8  9/1/17 12:25 AM                 66.254               0.004908
# 9  9/1/17 12:28 AM                 66.290               0.005631

# %%
df2=pd.read_csv(data_url4)
df2.head(10)
# Out:
#      Date and Time  Water Temperature (F)  Estimated Flow Rate (m3/s)
# 0   10/1/2017 0:19                 62.096                    0.029084
# 1   10/1/2017 0:30                 61.916                    0.032962
# 2   10/1/2017 0:36                 61.862                    0.026500
# 3  10/1/2017 13:25                 60.512                    0.018774
# 4  10/1/2017 13:35                 60.494                    0.016194
# 5  10/1/2017 13:48                 60.566                    0.013135
# 6  10/1/2017 14:33                 60.836                    0.014517
# 7  10/1/2017 16:40                 62.114                    0.011127
# 8  10/1/2017 17:32                 62.204                    0.006843
# 9  10/1/2017 17:46                 62.150                    0.004584

# %% [markdown]
# ## Exploring Data
# Generate **two** scatter plots: one for the estimated flow rate data in September 2017 and the other for the estimated flow rate data in October 2017. Make sure to provide the title, x axis label and y axis label for your scatter plots.

# %% [markdown]
# ## Scatter Plot 1

# %%
plt.figure(figsize=(20,12))
plt.scatter(df1['Date and Time'],df1['Est. Flow Rate[m^3/s]'])
plt.title('Scatter Plot for September 2017')
plt.xlabel('Date and Time')
plt.ylabel('Est. Flow Rate[m^3/s]')
plt.show()

# %%
# Out:
# Empty DataFrame
# Columns: [Date and Time, Water Temperature (F), Est. Flow Rate[m^3/s]]
# Index: []

# %% [markdown]
# Comment on the trend of Est. Flow Rate[m^3/s] for September 2017.
# <br>
# Answer: The flow rate of the water is higher in the beginning and towards the end of September and overall has a strong trendline as majority of points are packed tightly together. While most of the data is around 0.
# <BR>

# %% [markdown]
# ## Scatter Plot 2

# %%
df12=df1[df1['Date and Time'].astype(str).str[:7]=='9/28/17']
df12.head(10)
# Out:
#           Date and Time  Water Temperature (F)  Est. Flow Rate[m^3/s]
# 12765  9/28/17 12:00 AM                 66.560               0.001469
# 12766  9/28/17 12:03 AM                 66.560               0.001471
# 12767  9/28/17 12:06 AM                 66.542               0.006522
# 12768  9/28/17 12:09 AM                 66.560               0.004293
# 12769  9/28/17 12:12 AM                 66.542               0.002252
# 12770  9/28/17 12:15 AM                 66.560               0.009034
# 12771  9/28/17 12:18 AM                 66.542               0.005067
# 12772  9/28/17 12:21 AM                 66.578              -0.001823
# 12773  9/28/17 12:24 AM                 66.542              -0.007261
# 12774  9/28/17 12:27 AM                 66.524              -0.011683

# %%
plt.figure(figsize=(20,12))
plt.scatter(df2['Date and Time'],df2['Estimated Flow Rate (m3/s)'])
plt.title('Scatter Plot for October 2017')
plt.xlabel('Date and Time')
plt.ylabel('Estimated Flow Rate (m3/s)')
plt.show()

# %% [markdown]
# Comment on the trend of Est. Flow Rate[m^3/s] for October 2017.
# <br>
# **Answer:**
# <BR>

# %% [markdown]
# The flow rate in October has peaked in the beginning of the month and has also increased from the average flow rate during the end of October. with most of its data points being around 0.

# %% [markdown]
# ## Histogram Plotting
# Plot a histogram for Est. Flow Rate  data of September 2017. Be sure to include proper titles and axis labels on each of your plots.<br>
# Plot a histogram for Est. Flow Rate data of October 2017. Be sure to include proper titles and axis labels on each of your plots.

# %%
plt.hist(df1['Est. Flow Rate[m^3/s]'])
plt.title('Histogram for September 2017')
plt.xlabel('Est. Flow Rate[m^3/s]')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(df2['Estimated Flow Rate (m3/s)'])
plt.title('Histogram for October 2017')
plt.xlabel('Estimated Flow Rate (m3/s)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ***Comment on the shape of both distributions.***
# <br>
# ***Answer:***
# <br> Both graphs are heavily skewed to the right.
# <br>

# %% [markdown]
# # Boxplot
#
# Generate a boxplot for Est. Flow Rate data of September 2017.<br>
# *Generate* a boxplot for Est. Flow Rate data of October 2017.

# %%
boxplot1=df1.boxplot(column='Est. Flow Rate[m^3/s]')
plt.title('Boxplot for September 2017')
plt.xlabel('Est. Flow Rate[m^3/s]')
# Out:
# Text(0.5, 0, 'Est. Flow Rate[m^3/s]')

# %%
boxplot2=df2.boxplot(column='Estimated Flow Rate (m3/s)')
plt.title('Boxplot for October 2017')
plt.xlabel('Estimated Flow Rate (m3/s)')
# Out:
# Text(0.5, 0, 'Estimated Flow Rate (m3/s)')

# %% [markdown]
# ***Comment on both boxplots***
# <br>
# ***Answer:*** <br>

# %% [markdown]
#  The whiskers show that most values are close to zero and the tail shows how the values can get significantly higher than the median(outliers).

# %% [markdown]
# #Confidence Interval
#
# Generate the 95% confidence interval for the mean estimated flow rate of September 2017.

# %%
stats.t.interval(0.95, len(df1['Est. Flow Rate[m^3/s]'])-1, loc=np.mean(df1['Est. Flow Rate[m^3/s]']), scale=stats.sem(df1['Est. Flow Rate[m^3/s]']))
# Out:
# (np.float64(-0.0005891216373351925), np.float64(0.0006043853208151762))

# %% [markdown]
# Interpret the confidence interval you generated.<br>
# ***Answer:***

# %% [markdown]
# The 95% confidence interval for the mean estimated flow rate of September

# %% [markdown]
# # Hypothesis testing
# Suppose we are interested in testing if the mean estimated flow rate from September 2017 is statisticlly different from the mean estimated flow rate from October 2017.

# %% [markdown]
# ***Question***<br>
# How many samples are there in this experiment? What are they?<br>
# ***Answer***

# %% [markdown]
# There are two samples in this experiment:
#
# The sample of estimated flow rates from September 2017
#
# The sample of estimated flow rates from October 2017

# %% [markdown]
# # Independent Variable and Dependent Variable

# %% [markdown]
# ***Question***<br>
# What is the independent variable and what is the dependent variable of this experiment?

# %% [markdown]
# ***Answer***

# %% [markdown]
# Independent Variable: Month (September 2017 vs. October 2017)
#
# Dependent Variable: Estimated flow rate

# %% [markdown]
# ***Question***<br>
# What are the assumptions for the two sample t test?

# %% [markdown]
# ***Answer***

# %% [markdown]
# The two samples are independent of each other.

# %% [markdown]
# The data in each group are approximately normally distributed.

# %% [markdown]
# The two populations have equal variances

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# #Hypothesis testing
# Use the appropraite statistical analysis technique.<br>
# Conduct model adequacy and comment on the model adequacy.<br>
# Conduct hypothesis testing

# %%
t_statistic, p_value = stats.ttest_ind(df1['Est. Flow Rate[m^3/s]'], df2['Estimated Flow Rate (m3/s)'])

# %%
print(f"T-statistic: {t_statistic}")
print(f"P-value: {p_value}")

# %% [markdown]
# Normality: Use a histogram, Q–Q plot, or Shapiro–Wilk test to verify approximate normality of each sample.
#
# Equal Variances: Use Levene’s test or an F-test to check for equal variances.
#
# Independence: Verify that samples were collected independently (no repeated measures).

# %% [markdown]
# Based on the tests, what can you conclude about the model assumptions?
# <br>
# **Answer:**

# %% [markdown]
# If the p-value < α (e.g., 0.05), reject H₀ and conclude that the mean flow rates in September and October 2017 are significantly different.
# If the p-value ≥ α, fail to reject H₀, meaning there is no statistical evidence of a difference between the two months.

# %% [markdown]
# # 6-Step Hypothesis Testing

# %% [markdown]
# 1. State the hypotheses (H₀ and H₁)

# %% [markdown]
# 2. Select significance level (α)

# %% [markdown]
# 3. Choose the appropriate test statistic (t-test)

# %% [markdown]
# 4. Compute the test statistic and p-value

# %% [markdown]
# 5. Make a decision (Reject or fail to reject H₀)

# %% [markdown]
# 6. Interpret the result in the context of the experiment

# %% [markdown]
# In the space below, type your experience with your colab project experience. What you like, what you dislike and what you would like to experience in the future colab projects.

# %% [markdown]
# Our group enjoyed working on these projects as it provided us experience with coding while also enhancing out statistic skills with interpreting data/graphs. Overall, there was not anything to dislike as both projects where able to get done with little to no trouble. For future colab projects, I would suggest possibly learning a little bit about Python before starting the project.
